# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import time

url = "https://www.moneycontrol.com/"

# %%
chromedriver = r"D:\Programming Segate 25 Jul 2019\Prgramming_19-05-2019\WEB\chromedriver"
browser = webdriver.Chrome(chromedriver)
browser.get(url)

# %%
def search_stock(stockN):
    searchBar = browser.find_element_by_id('search_str')
    time.sleep(2)
    searchBar.send_keys(stockN)
    time.sleep(2)
    searchBar.send_keys(Keys.ENTER)

# %%
def balance_sheet_url():
    bs_url = browser.find_element_by_partial_link_text('Balance Sheet').get_attribute('href')
    browser.get(bs_url)

# %%
def old_format():
    of_url = browser.find_element_by_partial_link_text('Old Format').get_attribute('href')
    browser.get(of_url)

# %%
search_stock("GAIL")
time.sleep(2)
balance_sheet_url()
time.sleep(2)
old_format()

# %% [markdown]
# ## Share Capital - kind of (property or asset) - not good to dilute, better to increase
#
# ideally Reserves inc, Debt dec
#
# <br>
# <br>
# <br>
#
# To understand share capital, think about a fictional company issuing shares for the first time. Imagine, Company ABC issues 1000 shares, with each share having a face value of Rs.10 each. The share capital in this case would be Rs.10 x 1000 = Rs.10,000/- (Face value X number of shares).
#
# <br>
# <br>
#
# Number of shares = Share Capital / FV

# %%
def get_stock_data(stockN):
    searchBar = browser.find_element_by_xpath('//*[@id="search_str"]')
    searchBar.send_keys(stockN)
    searchBar.send_keys(Keys.ENTER)
      
    str1 = '//*[@id="mktdet_2"]/div[1]/div['
    str2 = ']/div[2]'
   
    R = ['1','3','6']
    C = []
    for r in R:
        string = str1 + r + str2 
        element = browser.find_element_by_xpath(string)
        elm = coma_r(element.text)
        C.append(float(elm))
            
    nst_pb = '//*[@id="mktdet_2"]/div[2]/div[3]/div[2]'
    e1 = browser.find_element_by_xpath(nst_pb)
    
    st_p = '//*[@id="Nse_Prc_tick"]/strong'
    e2 = browser.find_element_by_xpath(st_p)
    
    Price = float(e2.text)
    PB = float(coma_r(e1.text))
    MC = C[0]    
    BV = C[1]       
    PE_Ind = C[2]
    Shares = np.floor(MC/Price) 
    
    finantials = browser.find_element_by_xpath('//*[@id="slider"]/dt[7]/a')
    finantials.send_keys(Keys.ENTER)
    
    bs = browser.find_element_by_xpath('//*[@id="slider"]/dd[3]/ul/li[1]/a')
    bs.send_keys(Keys.ENTER)
    
    cons = browser.find_element_by_xpath('//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div/ul/li[2]/a')
    cons.send_keys(Keys.ENTER)
    
    old = browser.find_element_by_xpath('//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[1]/div[1]/div/ul/li[2]/a')
    old.send_keys(Keys.ENTER)
    
    
    str1 = '//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/table[2]/tbody/tr['
    str2 = ']/td['
    str3 = ']'
    stry = ['2','3','4','5','6']
   
    R1 = ['6','8','12']
    C1 = []
    for r in R1:
        Data = []
        for s in stry:
            string = str1 + r + str2 + s + str3
            element = browser.find_element_by_xpath(string)
            elm = coma_r(element.text)
            Data.append(float(elm))
        
        C1.append(Data)
    
    Total_Share_Capital = C1[0]    # INS
    Reserves = C1[1]     # IPS
    Total_Debt = C1[2]   #INS
      
    yr = browser.find_element_by_xpath('//*[@id="slider"]/dd[3]/ul/li[6]/a')
    yr.send_keys(Keys.ENTER)
    
    cons = browser.find_element_by_xpath('//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div/ul/li[2]/a')
    cons.send_keys(Keys.ENTER)
        
    
    str1 = '//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/table[2]/tbody/tr['
    str2 = ']/td['
    str3 = ']'
    stry = ['2','3','4','5','6']
   
    R = ['5','9','13','24','32','40']
    C = []
    for r in R:
        Data = []
        for s in stry:
            string = str1 + r + str2 + s + str3
            element = browser.find_element_by_xpath(string)
            elm = coma_r(element.text)
            Data.append(float(elm))
        
        C.append(Data)
    
    Sales = C[0]       # IPS
    Raw_Materials_Consumption = C[1]    #IPS
    Employee_Cost = C[2]       #IPS
    Interest = C[3]              # INS
    Net_Profit = C[4]
    EPS = C[5]
    
    rat = browser.find_element_by_xpath('//*[@id="slider"]/dd[3]/ul/li[8]/a')
    rat.send_keys(Keys.ENTER)
    
    cons = browser.find_element_by_xpath('//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div/ul/li[2]/a')
    cons.send_keys(Keys.ENTER)
        
    
    str1 = '//*[@id="mc_mainWrapper"]/div[3]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/table[2]/tbody/tr['
    str2 = ']/td['
    str3 = ']'
    stry = ['2','3','4','5','6']
   
    R = ['10','24','40','42']
    C = []
    for r in R:
        Data = []
        for s in stry:
            string = str1 + r + str2 + s + str3
            element = browser.find_element_by_xpath(string)
            elm = coma_r(element.text)
            Data.append(float(elm))
        
        C.append(Data)
    
    #BV = C[0]       # IPS
    ROE = C[1]    #IPS
    EV = C[2]       #IPS
    EV_EBITDA = C[3]
    EBITDA = S_Div(EV,EV_EBITDA)    
    PE = Price/EPS[0]
    
    browser.close()
    
    return EBITDA,PE,Total_Share_Capital,Reserves,Total_Debt,Sales,Raw_Materials_Consumption,Employee_Cost,Interest,Net_Profit,EPS,ROE,EV,EV_EBITDA,Shares,Price,PB,MC,BV,PE_Ind
