# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
class Agent():
    def __init__(self,lr,gamma,n_actions,n_states,eps_start,eps_end,eps_dec):
        
        self.lr = lr
        self.gamma = gamma
        self.n_actions = n_actions
        self.n_states = n_states
        self.epsilon = eps_start
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        
        self.Q = {}
        
        self.init_Q()
        
    def init_Q(self):
        for state in range(self.n_states):
            for action in range(self.n_actions):
                self.Q[(state,action)] = 0
    
    def choose_action(self,state):
        if np.random.random() < self.epsilon:
            action = np.random.choice([i for i in range(self.n_actions)])
        else:
            actions =np.array([self.Q[(state,a)] for a in range(self.n_actions)])
            action = np.argmax(actions)
        
        return action
    
    def decrement_epsilon(self):
        self.epsilon = self.epsilon *self.eps_dec if self.epsilon > self.eps_min else self.eps_min
        
    def learn(self,state,action,reward,state_):
        actions = np.array([self.Q[(state,a)] for a in range(self.n_actions)])
        a_max = np.argmax(actions)
        
        self.Q[(state,action)] += self.lr*(reward + self.gamma*self.Q[(state,a_max)] - self.Q[(state,action)])
        
        #qa_dash_max = 
        #self.Q[(state,action)] += self.lr*(reward + self.gamma*self.Q[(state,a_max)] - self.Q[(state,action)])
       
        
        
        self.decrement_epsilon()

# %%
env = gym.make('FrozenLake-v0')
agent = Agent(lr=0.001,gamma=0.9,eps_start=1,eps_end=0.001,eps_dec=0.9999995,n_actions=4,n_states=16)

n_games = 500000
win_pct = []
scores = []

for i in range(n_games):
    done = False
    obs = env.reset()
    score = 0
    while not done:
        
        action = agent.choose_action(obs)
        obs_,reward,done,info = env.step(action)
        agent.learn(obs,action,reward,obs_)
        
        score += reward
        obs = obs_
    scores.append(score)
    
    if i%100 == 0:
        average = np.mean(scores[-100:])
        win_pct.append(average)
        if i%1000 == 0:
            print('episode ',i, 'win per %.2f' % average, 'epsilon %.2f' % agent.epsilon)

plt.plot(win_pct)
plt.show()
# Out:
# episode  0 win per 0.00 epsilon 1.00
# episode  1000 win per 0.01 epsilon 1.00
# episode  2000 win per 0.01 epsilon 0.99
# episode  3000 win per 0.00 epsilon 0.99
# episode  4000 win per 0.01 epsilon 0.98
# episode  5000 win per 0.02 epsilon 0.98
# episode  6000 win per 0.02 epsilon 0.98
# episode  7000 win per 0.01 epsilon 0.97
# episode  8000 win per 0.02 epsilon 0.97
# episode  9000 win per 0.01 epsilon 0.97
# episode  10000 win per 0.02 epsilon 0.96
# episode  11000 win per 0.01 epsilon 0.96
# episode  12000 win per 0.01 epsilon 0.96
# episode  13000 win per 0.00 epsilon 0.95
# episode  14000 win per 0.01 epsilon 0.95
# episode  15000 win per 0.00 epsilon 0.94
# episode  16000 win per 0.00 epsilon 0.94
# episode  17000 win per 0.01 epsilon 0.94
# episode  18000 win per 0.01 epsilon 0.93
# episode  19000 win per 0.03 epsilon 0.93
# episode  20000 win per 0.01 epsilon 0.93
# episode  21000 win per 0.02 epsilon 0.92
# episode  22000 win per 0.02 epsilon 0.92
# episode  23000 win per 0.01 epsilon 0.92
# episode  24000 win per 0.00 epsilon 0.91
# episode  25000 win per 0.01 epsilon 0.91
# episode  26000 win per 0.00 epsilon 0.90
# episode  27000 win per 0.01 epsilon 0.90
# episode  28000 win per 0.02 epsilon 0.90
# episode  29000 win per 0.00 epsilon 0.89
# episode  30000 win per 0.00 epsilon 0.89
# episode  31000 win per 0.01 epsilon 0.89
# episode  32000 win per 0.01 epsilon 0.88
# episode  33000 win per 0.03 epsilon 0.88
# episode  34000 win per 0.01 epsilon 0.88
# episode  35000 win per 0.01 epsilon 0.87
# episode  36000 win per 0.03 epsilon 0.87
# episode  37000 win per 0.01 epsilon 0.87
# episode  38000 win per 0.02 epsilon 0.86
# episode  39000 win per 0.00 epsilon 0.86
# episode  40000 win per 0.00 epsilon 0.86
# episode  41000 win per 0.02 epsilon 0.85
# episode  42000 win per 0.02 epsilon 0.85
# episode  43000 win per 0.00 epsilon 0.85
# episode  44000 win per 0.01 epsilon 0.84
# episode  45000 win per 0.01 epsilon 0.84
# episode  46000 win per 0.04 epsilon 0.84
# episode  47000 win per 0.00 epsilon 0.83
# episode  48000 win per 0.00 epsilon 0.83
# episode  49000 win per 0.01 epsilon 0.83
# episode  50000 win per 0.02 epsilon 0.82
# episode  51000 win per 0.01 epsilon 0.82
# episode  52000 win per 0.03 epsilon 0.82
# episode  53000 win per 0.01 epsilon 0.81
# episode  54000 win per 0.02 epsilon 0.81
# episode  55000 win per 0.02 epsilon 0.81
# episode  56000 win per 0.02 epsilon 0.80
# episode  57000 win per 0.00 epsilon 0.80
# episode  58000 win per 0.02 epsilon 0.80
# episode  59000 win per 0.00 epsilon 0.79
# episode  60000 win per 0.04 epsilon 0.79
# episode  61000 win per 0.01 epsilon 0.79
# episode  62000 win per 0.01 epsilon 0.78
# episode  63000 win per 0.02 epsilon 0.78
# episode  64000 win per 0.01 epsilon 0.78
# episode  65000 win per 0.00 epsilon 0.77
# episode  66000 win per 0.02 epsilon 0.77
# episode  67000 win per 0.03 epsilon 0.77
# episode  68000 win per 0.02 epsilon 0.76
# episode  69000 win per 0.01 epsilon 0.76
# episode  70000 win per 0.03 epsilon 0.76
# episode  71000 win per 0.02 epsilon 0.75
# episode  72000 win per 0.02 epsilon 0.75
# episode  73000 win per 0.01 epsilon 0.75
# episode  74000 win per 0.01 epsilon 0.74
# episode  75000 win per 0.02 epsilon 0.74
# episode  76000 win per 0.00 epsilon 0.74
# episode  77000 win per 0.02 epsilon 0.73
# episode  78000 win per 0.01 epsilon 0.73
# episode  79000 win per 0.00 epsilon 0.73
# episode  80000 win per 0.00 epsilon 0.73
# episode  81000 win per 0.02 epsilon 0.72
# episode  82000 win per 0.02 epsilon 0.72
# episode  83000 win per 0.02 epsilon 0.72
# episode  84000 win per 0.02 epsilon 0.71
# episode  85000 win per 0.02 epsilon 0.71
# episode  86000 win per 0.02 epsilon 0.71
# episode  87000 win per 0.02 epsilon 0.70
# episode  88000 win per 0.04 epsilon 0.70
# episode  89000 win per 0.02 epsilon 0.70
# episode  90000 win per 0.01 epsilon 0.69
# episode  91000 win per 0.02 epsilon 0.69
# episode  92000 win per 0.00 epsilon 0.69
# episode  93000 win per 0.03 epsilon 0.69
# episode  94000 win per 0.00 epsilon 0.68
# episode  95000 win per 0.01 epsilon 0.68
# episode  96000 win per 0.04 epsilon 0.68
# episode  97000 win per 0.00 epsilon 0.67
# episode  98000 win per 0.01 epsilon 0.67
# episode  99000 win per 0.02 epsilon 0.67
# episode  100000 win per 0.00 epsilon 0.67
# episode  101000 win per 0.02 epsilon 0.66
# episode  102000 win per 0.00 epsilon 0.66
# episode  103000 win per 0.03 epsilon 0.66
# episode  104000 win per 0.00 epsilon 0.65
# episode  105000 win per 0.01 epsilon 0.65
# episode  106000 win per 0.02 epsilon 0.65
# episode  107000 win per 0.00 epsilon 0.65
# episode  108000 win per 0.02 epsilon 0.64
# episode  109000 win per 0.01 epsilon 0.64
# episode  110000 win per 0.02 epsilon 0.64
# episode  111000 win per 0.02 epsilon 0.63
# episode  112000 win per 0.02 epsilon 0.63
# episode  113000 win per 0.00 epsilon 0.63
# episode  114000 win per 0.00 epsilon 0.63
# episode  115000 win per 0.04 epsilon 0.62
# episode  116000 win per 0.00 epsilon 0.62
# episode  117000 win per 0.01 epsilon 0.62
# episode  118000 win per 0.01 epsilon 0.61
# episode  119000 win per 0.00 epsilon 0.61
# episode  120000 win per 0.00 epsilon 0.61
# episode  121000 win per 0.01 epsilon 0.61
# episode  122000 win per 0.01 epsilon 0.60
# episode  123000 win per 0.00 epsilon 0.60
# episode  124000 win per 0.02 epsilon 0.60
# episode  125000 win per 0.01 epsilon 0.59
# episode  126000 win per 0.02 epsilon 0.59
# episode  127000 win per 0.01 epsilon 0.59
# episode  128000 win per 0.02 epsilon 0.59
# episode  129000 win per 0.00 epsilon 0.58
# episode  130000 win per 0.01 epsilon 0.58
# episode  131000 win per 0.00 epsilon 0.58
# episode  132000 win per 0.00 epsilon 0.58
# episode  133000 win per 0.02 epsilon 0.57
# episode  134000 win per 0.01 epsilon 0.57
# episode  135000 win per 0.01 epsilon 0.57
# episode  136000 win per 0.02 epsilon 0.57
# episode  137000 win per 0.01 epsilon 0.56
# episode  138000 win per 0.00 epsilon 0.56
# episode  139000 win per 0.02 epsilon 0.56
# episode  140000 win per 0.01 epsilon 0.56
# episode  141000 win per 0.01 epsilon 0.55
# episode  142000 win per 0.01 epsilon 0.55
# episode  143000 win per 0.01 epsilon 0.55
# episode  144000 win per 0.00 epsilon 0.54
# episode  145000 win per 0.00 epsilon 0.54
# episode  146000 win per 0.01 epsilon 0.54
# episode  147000 win per 0.00 epsilon 0.54
# episode  148000 win per 0.02 epsilon 0.53
# episode  149000 win per 0.03 epsilon 0.53
# episode  150000 win per 0.02 epsilon 0.53
# episode  151000 win per 0.01 epsilon 0.53
# episode  152000 win per 0.01 epsilon 0.52
# episode  153000 win per 0.01 epsilon 0.52
# episode  154000 win per 0.01 epsilon 0.52
# episode  155000 win per 0.02 epsilon 0.52
# episode  156000 win per 0.02 epsilon 0.51
# episode  157000 win per 0.00 epsilon 0.51
# episode  158000 win per 0.00 epsilon 0.51
# episode  159000 win per 0.03 epsilon 0.51
# episode  160000 win per 0.01 epsilon 0.50
# episode  161000 win per 0.01 epsilon 0.50
# episode  162000 win per 0.00 epsilon 0.50
# episode  163000 win per 0.02 epsilon 0.50
# episode  164000 win per 0.01 epsilon 0.50
# episode  165000 win per 0.01 epsilon 0.49
# episode  166000 win per 0.04 epsilon 0.49
# episode  167000 win per 0.01 epsilon 0.49
# episode  168000 win per 0.04 epsilon 0.49
# episode  169000 win per 0.01 epsilon 0.48
# episode  170000 win per 0.02 epsilon 0.48
# episode  171000 win per 0.01 epsilon 0.48
# episode  172000 win per 0.00 epsilon 0.48
# episode  173000 win per 0.00 epsilon 0.47
# episode  174000 win per 0.02 epsilon 0.47
# episode  175000 win per 0.01 epsilon 0.47
# episode  176000 win per 0.02 epsilon 0.47
# episode  177000 win per 0.01 epsilon 0.46
# episode  178000 win per 0.02 epsilon 0.46
# episode  179000 win per 0.01 epsilon 0.46
# episode  180000 win per 0.02 epsilon 0.46
# episode  181000 win per 0.02 epsilon 0.46
# episode  182000 win per 0.02 epsilon 0.45
# episode  183000 win per 0.01 epsilon 0.45
# episode  184000 win per 0.00 epsilon 0.45
# episode  185000 win per 0.00 epsilon 0.45
# episode  186000 win per 0.00 epsilon 0.44
# episode  187000 win per 0.01 epsilon 0.44
# episode  188000 win per 0.00 epsilon 0.44
# episode  189000 win per 0.01 epsilon 0.44
# episode  190000 win per 0.01 epsilon 0.43
# episode  191000 win per 0.00 epsilon 0.43
# episode  192000 win per 0.02 epsilon 0.43
# episode  193000 win per 0.00 epsilon 0.43
# episode  194000 win per 0.01 epsilon 0.43
# episode  195000 win per 0.01 epsilon 0.42
# episode  196000 win per 0.01 epsilon 0.42
# episode  197000 win per 0.01 epsilon 0.42
# episode  198000 win per 0.00 epsilon 0.42
# episode  199000 win per 0.00 epsilon 0.42
# episode  200000 win per 0.00 epsilon 0.41
# episode  201000 win per 0.02 epsilon 0.41
# episode  202000 win per 0.00 epsilon 0.41
# episode  203000 win per 0.02 epsilon 0.41
# episode  204000 win per 0.02 epsilon 0.41
# episode  205000 win per 0.00 epsilon 0.40
# episode  206000 win per 0.01 epsilon 0.40
# episode  207000 win per 0.03 epsilon 0.40
# episode  208000 win per 0.02 epsilon 0.40
# episode  209000 win per 0.01 epsilon 0.39
# episode  210000 win per 0.00 epsilon 0.39
# episode  211000 win per 0.01 epsilon 0.39
# episode  212000 win per 0.00 epsilon 0.39
# episode  213000 win per 0.00 epsilon 0.39
# episode  214000 win per 0.01 epsilon 0.38
# episode  215000 win per 0.03 epsilon 0.38
# episode  216000 win per 0.00 epsilon 0.38
# episode  217000 win per 0.02 epsilon 0.38
# episode  218000 win per 0.01 epsilon 0.38
# episode  219000 win per 0.00 epsilon 0.37
# episode  220000 win per 0.00 epsilon 0.37
# episode  221000 win per 0.00 epsilon 0.37
# episode  222000 win per 0.00 epsilon 0.37
# episode  223000 win per 0.01 epsilon 0.37
# episode  224000 win per 0.00 epsilon 0.36
# episode  225000 win per 0.01 epsilon 0.36
# episode  226000 win per 0.01 epsilon 0.36
# episode  227000 win per 0.02 epsilon 0.36
# episode  228000 win per 0.00 epsilon 0.36
# episode  229000 win per 0.00 epsilon 0.35
# episode  230000 win per 0.00 epsilon 0.35
# episode  231000 win per 0.01 epsilon 0.35
# episode  232000 win per 0.00 epsilon 0.35
# episode  233000 win per 0.00 epsilon 0.35
# episode  234000 win per 0.01 epsilon 0.34
# episode  235000 win per 0.00 epsilon 0.34
# episode  236000 win per 0.00 epsilon 0.34
# episode  237000 win per 0.01 epsilon 0.34
# episode  238000 win per 0.02 epsilon 0.34
# episode  239000 win per 0.00 epsilon 0.34
# episode  240000 win per 0.02 epsilon 0.33
# episode  241000 win per 0.00 epsilon 0.33
# episode  242000 win per 0.00 epsilon 0.33
# episode  243000 win per 0.02 epsilon 0.33
# episode  244000 win per 0.02 epsilon 0.33
# episode  245000 win per 0.02 epsilon 0.32
# episode  246000 win per 0.01 epsilon 0.32
# episode  247000 win per 0.01 epsilon 0.32
# episode  248000 win per 0.01 epsilon 0.32
# episode  249000 win per 0.00 epsilon 0.32
# episode  250000 win per 0.00 epsilon 0.32
# episode  251000 win per 0.00 epsilon 0.31
# episode  252000 win per 0.00 epsilon 0.31
# episode  253000 win per 0.00 epsilon 0.31
# episode  254000 win per 0.01 epsilon 0.31
# episode  255000 win per 0.01 epsilon 0.31
# episode  256000 win per 0.01 epsilon 0.30
# episode  257000 win per 0.00 epsilon 0.30
# episode  258000 win per 0.00 epsilon 0.30
# episode  259000 win per 0.00 epsilon 0.30
# episode  260000 win per 0.00 epsilon 0.30
# episode  261000 win per 0.00 epsilon 0.30
# episode  262000 win per 0.01 epsilon 0.29
# episode  263000 win per 0.00 epsilon 0.29
# episode  264000 win per 0.00 epsilon 0.29
# episode  265000 win per 0.00 epsilon 0.29
# episode  266000 win per 0.00 epsilon 0.29
# episode  267000 win per 0.01 epsilon 0.29
# episode  268000 win per 0.00 epsilon 0.28
# episode  269000 win per 0.00 epsilon 0.28
# episode  270000 win per 0.00 epsilon 0.28
# episode  271000 win per 0.01 epsilon 0.28
# episode  272000 win per 0.01 epsilon 0.28
# episode  273000 win per 0.02 epsilon 0.28
# episode  274000 win per 0.00 epsilon 0.27
# episode  275000 win per 0.00 epsilon 0.27
# episode  276000 win per 0.01 epsilon 0.27
# episode  277000 win per 0.00 epsilon 0.27
# episode  278000 win per 0.00 epsilon 0.27
# episode  279000 win per 0.01 epsilon 0.27
# episode  280000 win per 0.00 epsilon 0.26
# episode  281000 win per 0.02 epsilon 0.26
# episode  282000 win per 0.02 epsilon 0.26
# episode  283000 win per 0.00 epsilon 0.26
# episode  284000 win per 0.01 epsilon 0.26
# episode  285000 win per 0.00 epsilon 0.26
# episode  286000 win per 0.01 epsilon 0.26
# episode  287000 win per 0.00 epsilon 0.25
# episode  288000 win per 0.01 epsilon 0.25
# episode  289000 win per 0.01 epsilon 0.25
# episode  290000 win per 0.01 epsilon 0.25
# episode  291000 win per 0.00 epsilon 0.25
# episode  292000 win per 0.00 epsilon 0.25
# episode  293000 win per 0.00 epsilon 0.24
# episode  294000 win per 0.01 epsilon 0.24
# episode  295000 win per 0.00 epsilon 0.24
# episode  296000 win per 0.02 epsilon 0.24
# episode  297000 win per 0.00 epsilon 0.24
# episode  298000 win per 0.00 epsilon 0.24
# episode  299000 win per 0.00 epsilon 0.24
# episode  300000 win per 0.00 epsilon 0.23
# episode  301000 win per 0.00 epsilon 0.23
# episode  302000 win per 0.00 epsilon 0.23
# episode  303000 win per 0.01 epsilon 0.23
# episode  304000 win per 0.00 epsilon 0.23
# episode  305000 win per 0.00 epsilon 0.23
# episode  306000 win per 0.01 epsilon 0.23
# episode  307000 win per 0.01 epsilon 0.22
# episode  308000 win per 0.01 epsilon 0.22
# episode  309000 win per 0.01 epsilon 0.22
# episode  310000 win per 0.00 epsilon 0.22
# episode  311000 win per 0.00 epsilon 0.22
# episode  312000 win per 0.00 epsilon 0.22
# episode  313000 win per 0.03 epsilon 0.22
# episode  314000 win per 0.00 epsilon 0.21
# episode  315000 win per 0.01 epsilon 0.21
# episode  316000 win per 0.00 epsilon 0.21
# episode  317000 win per 0.00 epsilon 0.21
# episode  318000 win per 0.00 epsilon 0.21
# episode  319000 win per 0.00 epsilon 0.21
# episode  320000 win per 0.00 epsilon 0.21
# episode  321000 win per 0.00 epsilon 0.21
# episode  322000 win per 0.00 epsilon 0.20
# episode  323000 win per 0.00 epsilon 0.20
# episode  324000 win per 0.01 epsilon 0.20
# episode  325000 win per 0.00 epsilon 0.20
# episode  326000 win per 0.00 epsilon 0.20
# episode  327000 win per 0.00 epsilon 0.20
# episode  328000 win per 0.00 epsilon 0.20
# episode  329000 win per 0.01 epsilon 0.20
# episode  330000 win per 0.00 epsilon 0.19
# episode  331000 win per 0.00 epsilon 0.19
# episode  332000 win per 0.00 epsilon 0.19
# episode  333000 win per 0.00 epsilon 0.19
# episode  334000 win per 0.00 epsilon 0.19
# episode  335000 win per 0.01 epsilon 0.19
# episode  336000 win per 0.01 epsilon 0.19
# episode  337000 win per 0.01 epsilon 0.19
# episode  338000 win per 0.00 epsilon 0.18
# episode  339000 win per 0.01 epsilon 0.18
# episode  340000 win per 0.01 epsilon 0.18
# episode  341000 win per 0.00 epsilon 0.18
# episode  342000 win per 0.01 epsilon 0.18
# episode  343000 win per 0.00 epsilon 0.18
# episode  344000 win per 0.00 epsilon 0.18
# episode  345000 win per 0.00 epsilon 0.18
# episode  346000 win per 0.00 epsilon 0.17
# episode  347000 win per 0.00 epsilon 0.17
# episode  348000 win per 0.00 epsilon 0.17
# episode  349000 win per 0.01 epsilon 0.17
# episode  350000 win per 0.01 epsilon 0.17
# episode  351000 win per 0.00 epsilon 0.17
# episode  352000 win per 0.00 epsilon 0.17
# episode  353000 win per 0.00 epsilon 0.17
# episode  354000 win per 0.00 epsilon 0.17
# episode  355000 win per 0.00 epsilon 0.16
# episode  356000 win per 0.00 epsilon 0.16
# episode  357000 win per 0.02 epsilon 0.16
# episode  358000 win per 0.00 epsilon 0.16
# episode  359000 win per 0.00 epsilon 0.16
# episode  360000 win per 0.00 epsilon 0.16
# episode  361000 win per 0.00 epsilon 0.16
# episode  362000 win per 0.00 epsilon 0.16
# episode  363000 win per 0.00 epsilon 0.16
# episode  364000 win per 0.00 epsilon 0.15
# episode  365000 win per 0.00 epsilon 0.15
# episode  366000 win per 0.00 epsilon 0.15
# episode  367000 win per 0.00 epsilon 0.15
# episode  368000 win per 0.02 epsilon 0.15
# episode  369000 win per 0.00 epsilon 0.15
# episode  370000 win per 0.01 epsilon 0.15
# episode  371000 win per 0.00 epsilon 0.15
# episode  372000 win per 0.00 epsilon 0.15
# episode  373000 win per 0.00 epsilon 0.14
# episode  374000 win per 0.01 epsilon 0.14
# episode  375000 win per 0.00 epsilon 0.14
# episode  376000 win per 0.00 epsilon 0.14
# episode  377000 win per 0.00 epsilon 0.14
# episode  378000 win per 0.00 epsilon 0.14
# episode  379000 win per 0.00 epsilon 0.14
# episode  380000 win per 0.00 epsilon 0.14
# episode  381000 win per 0.00 epsilon 0.14
# episode  382000 win per 0.00 epsilon 0.14
# episode  383000 win per 0.00 epsilon 0.13
# episode  384000 win per 0.00 epsilon 0.13
# episode  385000 win per 0.00 epsilon 0.13
# episode  386000 win per 0.00 epsilon 0.13
# episode  387000 win per 0.00 epsilon 0.13
# episode  388000 win per 0.00 epsilon 0.13
# episode  389000 win per 0.00 epsilon 0.13
# episode  390000 win per 0.01 epsilon 0.13
# episode  391000 win per 0.01 epsilon 0.13
# episode  392000 win per 0.03 epsilon 0.13
# episode  393000 win per 0.00 epsilon 0.13
# episode  394000 win per 0.00 epsilon 0.12
# episode  395000 win per 0.00 epsilon 0.12
# episode  396000 win per 0.00 epsilon 0.12
# episode  397000 win per 0.00 epsilon 0.12
# episode  398000 win per 0.01 epsilon 0.12
# episode  399000 win per 0.00 epsilon 0.12
# episode  400000 win per 0.01 epsilon 0.12
# episode  401000 win per 0.00 epsilon 0.12
# episode  402000 win per 0.00 epsilon 0.12
# episode  403000 win per 0.00 epsilon 0.12
# episode  404000 win per 0.00 epsilon 0.12
# episode  405000 win per 0.00 epsilon 0.12
# episode  406000 win per 0.00 epsilon 0.11
# episode  407000 win per 0.00 epsilon 0.11
# episode  408000 win per 0.01 epsilon 0.11
# episode  409000 win per 0.00 epsilon 0.11
# episode  410000 win per 0.00 epsilon 0.11
# episode  411000 win per 0.00 epsilon 0.11
# episode  412000 win per 0.00 epsilon 0.11
# episode  413000 win per 0.00 epsilon 0.11
# episode  414000 win per 0.00 epsilon 0.11
# episode  415000 win per 0.00 epsilon 0.11
# episode  416000 win per 0.00 epsilon 0.11
# episode  417000 win per 0.01 epsilon 0.11
# episode  418000 win per 0.00 epsilon 0.10
# episode  419000 win per 0.00 epsilon 0.10
# episode  420000 win per 0.00 epsilon 0.10
# episode  421000 win per 0.00 epsilon 0.10
# episode  422000 win per 0.00 epsilon 0.10
# episode  423000 win per 0.00 epsilon 0.10
# episode  424000 win per 0.00 epsilon 0.10
# episode  425000 win per 0.00 epsilon 0.10
# episode  426000 win per 0.00 epsilon 0.10
# episode  427000 win per 0.01 epsilon 0.10
# episode  428000 win per 0.00 epsilon 0.10
# episode  429000 win per 0.00 epsilon 0.10
# episode  430000 win per 0.00 epsilon 0.10
# episode  431000 win per 0.00 epsilon 0.09
# episode  432000 win per 0.00 epsilon 0.09
# episode  433000 win per 0.00 epsilon 0.09
# episode  434000 win per 0.00 epsilon 0.09
# episode  435000 win per 0.00 epsilon 0.09
# episode  436000 win per 0.00 epsilon 0.09
# episode  437000 win per 0.00 epsilon 0.09
# episode  438000 win per 0.00 epsilon 0.09
# episode  439000 win per 0.00 epsilon 0.09
# episode  440000 win per 0.00 epsilon 0.09
# episode  441000 win per 0.00 epsilon 0.09
# episode  442000 win per 0.00 epsilon 0.09
# episode  443000 win per 0.00 epsilon 0.09
# episode  444000 win per 0.00 epsilon 0.09
# episode  445000 win per 0.00 epsilon 0.09
# episode  446000 win per 0.00 epsilon 0.08
# episode  447000 win per 0.00 epsilon 0.08
# episode  448000 win per 0.01 epsilon 0.08
# episode  449000 win per 0.00 epsilon 0.08
# episode  450000 win per 0.00 epsilon 0.08
# episode  451000 win per 0.00 epsilon 0.08
# episode  452000 win per 0.00 epsilon 0.08
# episode  453000 win per 0.00 epsilon 0.08
# episode  454000 win per 0.00 epsilon 0.08
# episode  455000 win per 0.00 epsilon 0.08
# episode  456000 win per 0.00 epsilon 0.08
# episode  457000 win per 0.00 epsilon 0.08
# episode  458000 win per 0.00 epsilon 0.08
# episode  459000 win per 0.00 epsilon 0.08
# episode  460000 win per 0.00 epsilon 0.08
# episode  461000 win per 0.00 epsilon 0.08
# episode  462000 win per 0.00 epsilon 0.07
# episode  463000 win per 0.00 epsilon 0.07
# episode  464000 win per 0.00 epsilon 0.07
# episode  465000 win per 0.00 epsilon 0.07
# episode  466000 win per 0.00 epsilon 0.07
# episode  467000 win per 0.00 epsilon 0.07
# episode  468000 win per 0.00 epsilon 0.07
# episode  469000 win per 0.00 epsilon 0.07
# episode  470000 win per 0.00 epsilon 0.07
# episode  471000 win per 0.00 epsilon 0.07
# episode  472000 win per 0.01 epsilon 0.07
# episode  473000 win per 0.00 epsilon 0.07
# episode  474000 win per 0.00 epsilon 0.07
# episode  475000 win per 0.00 epsilon 0.07
# episode  476000 win per 0.00 epsilon 0.07
# episode  477000 win per 0.01 epsilon 0.07
# episode  478000 win per 0.00 epsilon 0.07
# episode  479000 win per 0.00 epsilon 0.07
# episode  480000 win per 0.00 epsilon 0.07
# episode  481000 win per 0.00 epsilon 0.06
# episode  482000 win per 0.00 epsilon 0.06
# episode  483000 win per 0.00 epsilon 0.06
# episode  484000 win per 0.00 epsilon 0.06
# episode  485000 win per 0.00 epsilon 0.06
# episode  486000 win per 0.00 epsilon 0.06
# episode  487000 win per 0.00 epsilon 0.06
# episode  488000 win per 0.00 epsilon 0.06
# episode  489000 win per 0.01 epsilon 0.06
# episode  490000 win per 0.00 epsilon 0.06
# episode  491000 win per 0.00 epsilon 0.06
# episode  492000 win per 0.00 epsilon 0.06
# episode  493000 win per 0.00 epsilon 0.06
# episode  494000 win per 0.00 epsilon 0.06
# episode  495000 win per 0.00 epsilon 0.06
# episode  496000 win per 0.00 epsilon 0.06
# episode  497000 win per 0.00 epsilon 0.06
# episode  498000 win per 0.00 epsilon 0.06
# episode  499000 win per 0.00 epsilon 0.06
