# %%
base_url = "https://api.exchangeratesapi.io/latest"

# %%
import requests

# %%
responce = requests.get(base_url)

# %%
responce.ok
# Out:
# True

# %%
responce.status_code
# Out:
# 200

# %%
responce.text
# Out:
# '{"rates":{"CAD":1.5118,"HKD":8.4052,"ISK":158.5,"PHP":54.681,"DKK":7.4598,"HUF":349.38,"CZK":27.251,"AUD":1.6613,"RON":4.828,"SEK":10.5875,"IDR":16229.26,"INR":81.9615,"BRL":6.3074,"RUB":79.8383,"HRK":7.5573,"JPY":115.34,"THB":34.958,"CHF":1.0529,"SGD":1.5326,"PLN":4.5482,"BGN":1.9558,"TRY":7.7252,"CNY":7.6719,"NOK":11.0695,"NZD":1.7668,"ZAR":19.997,"USD":1.0843,"MXN":25.9023,"ILS":3.8031,"GBP":0.87535,"KRW":1322.41,"MYR":4.6994},"base":"EUR","date":"2020-05-08"}'

# %%
responce.content
# Out:
# b'{"rates":{"CAD":1.5118,"HKD":8.4052,"ISK":158.5,"PHP":54.681,"DKK":7.4598,"HUF":349.38,"CZK":27.251,"AUD":1.6613,"RON":4.828,"SEK":10.5875,"IDR":16229.26,"INR":81.9615,"BRL":6.3074,"RUB":79.8383,"HRK":7.5573,"JPY":115.34,"THB":34.958,"CHF":1.0529,"SGD":1.5326,"PLN":4.5482,"BGN":1.9558,"TRY":7.7252,"CNY":7.6719,"NOK":11.0695,"NZD":1.7668,"ZAR":19.997,"USD":1.0843,"MXN":25.9023,"ILS":3.8031,"GBP":0.87535,"KRW":1322.41,"MYR":4.6994},"base":"EUR","date":"2020-05-08"}'

# %%
responce.json()
# Out:
# {'rates': {'CAD': 1.5118,
#   'HKD': 8.4052,
#   'ISK': 158.5,
#   'PHP': 54.681,
#   'DKK': 7.4598,
#   'HUF': 349.38,
#   'CZK': 27.251,
#   'AUD': 1.6613,
#   'RON': 4.828,
#   'SEK': 10.5875,
#   'IDR': 16229.26,
#   'INR': 81.9615,
#   'BRL': 6.3074,
#   'RUB': 79.8383,
#   'HRK': 7.5573,
#   'JPY': 115.34,
#   'THB': 34.958,
#   'CHF': 1.0529,
#   'SGD': 1.5326,
#   'PLN': 4.5482,
#   'BGN': 1.9558,
#   'TRY': 7.7252,
#   'CNY': 7.6719,
#   'NOK': 11.0695,
#   'NZD': 1.7668,
#   'ZAR': 19.997,
#   'USD': 1.0843,
#   'MXN': 25.9023,
#   'ILS': 3.8031,
#   'GBP': 0.87535,
#   'KRW': 1322.41,
#   'MYR': 4.6994},
#  'base': 'EUR',
#  'date': '2020-05-08'}

# %%
import json

# %%
print(json.dumps(responce.json(),indent = 4))
# Out:
# {
#     "rates": {
#         "CAD": 1.5118,
#         "HKD": 8.4052,
#         "ISK": 158.5,
#         "PHP": 54.681,
#         "DKK": 7.4598,
#         "HUF": 349.38,
#         "CZK": 27.251,
#         "AUD": 1.6613,
#         "RON": 4.828,
#         "SEK": 10.5875,
#         "IDR": 16229.26,
#         "INR": 81.9615,
#         "BRL": 6.3074,
#         "RUB": 79.8383,
#         "HRK": 7.5573,
#         "JPY": 115.34,
#         "THB": 34.958,
#         "CHF": 1.0529,
#         "SGD": 1.5326,
#         "PLN": 4.5482,
#         "BGN": 1.9558,
#         "TRY": 7.7252,
#         "CNY": 7.6719,
#         "NOK": 11.0695,
#         "NZD": 1.7668,
#         "ZAR": 19.997,
#         "USD": 1.0843,
#         "MXN": 25.9023,
#         "ILS": 3.8031,
#         "GBP": 0.87535,
#         "KRW": 1322.41,
#         "MYR": 4.6994
#     },
#     "base": "EUR",
#     "date": "2020-05-08"
# }

# %%
responce.json().keys()
# Out:
# dict_keys(['rates', 'base', 'date'])

# %%
param_url = base_url + "?symbols=USD,GBP"

# %%
responce = requests.get(param_url)

# %%
data = responce.json()

# %%
data['base']
# Out:
# 'EUR'

# %%
data
# Out:
# {'rates': {'USD': 1.0843, 'GBP': 0.87535}, 'base': 'EUR', 'date': '2020-05-08'}

# %%
u1 = "https://myaccount.esbecars.com/stationFacade/findStationById?stationId=100"

# %%
u = "https://myaccount.esbecars.com/stationFacade/findStationById"
#u = "https://myaccount.esbecars.com/stationFacade/findSitesInBounds"

# %%
requests.get(u)
# Out:
# <Response [200]>

# %%
d = requests.get(u,params={"stationId":"100"}).json()

# %%
import pandas as pd

# %%
d['data']['stationSockets'][0]
# Out:
# {'id': 200,
#  'deleted': False,
#  'dirty': False,
#  'identityKey': '1',
#  'name': 'Type-2',
#  'socketStatusId': 'AVAILABLE',
#  'maximumPower': 22.0,
#  'stationModelSocketSocketTypeId': 'TYPE_2_MENNEKES',
#  'stationModelSocketChargingMode': 'MODE3',
#  'stationModelSocketMaximumPower': 22.0,
#  'stationModelSocketChargingInstructions': '1| Swipe to charge;2| Connect cable;',
#  'stationIsManaged': True,
#  'stationInMaintenance': False,
#  'stationId': 100,
#  'socketPrices': [{'deleted': False,
#    'dirty': False,
#    'currency': 'EUR',
#    'stationId': 100,
#    'stationSocketId': 200,
#    'fixPrice': 0.0,
#    'socketType': 'TYPE_2_MENNEKES',
#    'displayDescription': '',
#    'futureReservationFee': 0.0}],
#  'reserved': False,
#  'siteDisplayName': 'The Square, Listowel, Kerry',
#  'inMaintenance': False,
#  'socketTariffsAreDirty': False,
#  'hasTeslaAdapter': False,
#  'safetyStationModelSocketBlocksChargingOnOtherSockets': False}

# %%
df = pd.DataFrame(d['data']['stationSockets'][0])

# %%
df
# Out:
#     id  deleted  dirty identityKey    name socketStatusId  maximumPower  \
# 0  200    False  False           1  Type-2      AVAILABLE          22.0
#
#   stationModelSocketSocketTypeId stationModelSocketChargingMode  \
# 0                TYPE_2_MENNEKES                          MODE3
#
#    stationModelSocketMaximumPower  ... stationIsManaged  stationInMaintenance  \
# 0                            22.0  ...             True                 False
#
#    stationId                                       socketPrices reserved  \
# 0        100  {'deleted': False, 'dirty': False, 'currency':...    False
#
#                siteDisplayName inMaintenance  socketTariffsAreDirty  \
# 0  The Square, Listowel, Kerry         False                  False
#
#    hasTeslaAdapter  safetyStationModelSocketBlocksChargingOnOtherSockets
# 0            False                                              False
#
# [1 rows x 21 columns]

# %%
a_id = '6cd26fb4'
key = '67ede641972e20b2735417f8014fc145'

# %%
api_endpoint = "https://api.edamam.com/api/nutrition-details"
url = api_endpoint + "?app_id=" + a_id +"&app_key=" + key

# %%
headers = {
    'Content-Type':'application'
}
recipe = {
    'title':'Cappuccino'
}

# %%
requests.post(url,headers=headers,json=recipe)
# Out:
# <Response [415]>

# %%
from bs4 import BeautifulSoup

# %%
base_url = "https://en.wikipedia.org/wiki/Music"
responce = requests.get(base_url)

# %%
html = responce.content
html[:100]
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<titl'

# %%
soup = BeautifulSoup(html,"html.parser")

# %%
with open('wiki_responce.html','wb') as file:
    file.write(soup.prettify('utf-8'))

# %%
soup.find('head')
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Music - Wikipedia</title>
# ...

# %%
links = soup.find_all('a')

# %%
links
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>,
# ...

# %%
len(links)
# Out:
# 2425

# %%
table = soup.find('tbody')

# %%
table.find_all('td')
# Out:
# [<td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:Music_lesson_Staatliche_Antikensammlungen_2421.jpg"><img alt="Music lesson Staatliche Antikensammlungen 2421.jpg" data-file-height="1849" data-file-width="2952" decoding="async" height="138" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Music_lesson_Staatliche_Antikensammlungen_2421.jpg/220px-Music_lesson_Staatliche_Antikensammlungen_2421.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Music_lesson_Staatliche_Antikensammlungen_2421.jpg/330px-Music_lesson_Staatliche_Antikensammlungen_2421.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Music_lesson_Staatliche_Antikensammlungen_2421.jpg/440px-Music_lesson_Staatliche_Antikensammlungen_2421.jpg 2x" width="220"/></a><div>A painting on an ancient Greek vase depicts a music lesson (c. 510 BC).</div></td>,
#  <td>Sound, silence, time</td>,
#  <td>Various</td>,
# ...

# %%
table.contents
# Out:
# [<tr><th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;background:antiquewhite;">Music</th></tr>,
# ...

# %%
table.parent.parent
# Out:
# <div class="mw-parser-output"><div class="hatnote navigation-not-searchable" role="note">For other uses, see <a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>.</div>
# <p class="mw-empty-elt">
# </p>
# <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">form of art using sound and silence</div>
# ...

# %%
soup.find('div', id='siteSub')
# Out:
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>

# %%
a = soup.find('div',attrs={'id':'siteSub'})

# %%
a.attrs
# Out:
# {'id': 'siteSub', 'class': ['noprint']}

# %%
a['id']
# Out:
# 'siteSub'

# %%
a.get('id')
# Out:
# 'siteSub'

# %%
a.text
# Out:
# 'From Wikipedia, the free encyclopedia'

# %%
a.string
# Out:
# 'From Wikipedia, the free encyclopedia'

# %%
burl = "https://www.immobilienscout24.de/Suche/de/nordrhein-westfalen/aachen-kreis/wohnung-mieten?enteredFrom=one_step_search"

# %%
responce = requests.get(burl)

# %%
responce
# Out:
# <Response [200]>

# %%
responce.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<html lang="de">\n<head>\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>\n  <meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/>\n  <meta name="msapplication-config" content="none"/>\n  <meta name="format-detection" content="telephone=no"/>\n  <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1"/>\n\n  \n\n  <link rel="manifest" href="/Suche/resources/manifest.json"/>\n\n  \n\n  <title>Wohnung mieten in Aachen (Kreis) - ImmobilienScout24</title>\n  \n    \n\n\n\n\n\n\n\n\n\n\t\n\t\t<meta name="robots" content="index, follow" />\n\t\n\t\n\n\n<meta name="description" content="Aachen (Kreis): Ein großes Angebot an Mietwohnungen in Aachen (Kreis) finden Sie bei ImmobilienScout24. Jetzt Ihre Traum-Wohnung in Aachen (Kreis) mieten."/>\n<meta name="keywords" content=""/>\n\n  <link rel="canonical" href="https://www.immobilienscout24.de/Suche/de/nordrhein-westfa
# ...

# %%
a
# Out:
# <bound method Response.json of <Response [200]>>

# %%
import sqlite3
